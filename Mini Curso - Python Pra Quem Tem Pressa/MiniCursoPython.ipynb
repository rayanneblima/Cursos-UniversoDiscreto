# %% [markdown]
# # **Mini Curso de Python - Set. 2020**
#
# Aluna: Rayanne Bertolace Lima
#
# [Aulas](https://www.youtube.com/playlist?list=PLpG5AqaFgtTjdBSDkwqxZbtzjY6BSmSCc)
#
# 1.   [Atividade 1](https://docs.google.com/document/d/1P1bwEcq19wrBQTMPx0nFszdN-g1h-6-DGyGHyCgMiwk/edit)
# 2.   [Atividade 2](https://docs.google.com/document/d/1ChPNwBHZLjkpLAVSNp5Mm-i1zVqX8q7NXA6aFRkOh6w/edit)
# 3. [Projeto Final](https://docs.google.com/document/d/1GV8GsERdfpuJN4su_NOar-nduMS7j2l4xM_MoHegxg8/edit)

# %%
# Atividade 1

def imprimeMenu():
  print("-----------Menu-----------")
  print("(1) Iniciar Jogo")
  print("(2) Mostrar Crédito")
  print("(3) Finalizar")
  print("--------------------------")
  opcao = input("Escolha uma opção: ")
  return int(opcao)

def iniciaJogo():
  print("\nIniciando jogo...")

def mostraCreditos():
  print("\nDesenvolvido por: Rayanne Bertolace Lima")

def finalizaJogo():
  print("\nFinalizando jogo...")

def main(): 
  opcao = imprimeMenu()
  while(opcao <= 0 or opcao > 3):
    print("\nOpção inválida! Escolha 1, 2 ou 3.\n")
    opcao = imprimeMenu()
    
  if opcao == 1:
    iniciaJogo()
  elif opcao == 2:
    mostraCreditos()
  elif opcao == 3:
    finalizaJogo()
  else:
    print("\nOpção inválida! Escolha 1, 2 ou 3.\n")
    imprimeMenu()

if __name__ == "__main__":
  main()

# %%
# Atividade 2

from random import randint

saude = 10
dinheiro = 10
vidasocial = 10
fama = 10
contador = 0


def mostraMochila():
    print(f"""
        Saúde: {saude}
        Dinheiro: {dinheiro}
        Vida Social: {vidasocial}
        Fama: {fama}
        """)
    print('--------------------------')


def main():

    global saude
    global dinheiro
    global vidasocial
    global fama
    global contador

    print('Olá! Vou te apresentar alguns cenários que acontecem no dia a dia de uma pessoa desenvolvedora e quero saber se você aceitaria ou não vivenciá-lo.')
    print('Lembre-se: Em cada cenário existe a possibilidade de ganhar ou perder saúde, dinheiro, vida social e fama. Seu objetivo é MANTER O EQUILÍBRIO.')
    print('Vamos começar?!')
    print('--------------------------')

    while (saude > 0 and dinheiro > 0 and vidasocial > 0 and fama > 0) and contador < 6:
        cenario = randint(1, 6)

        # Cenário 1: Desenvolvimento de um software promissor s-- d0 vs- f+
        if cenario == 1:
            contador += 1
            print('\nRecebeu uma proposta de desenvolvimento de um software promissor')
            resposta = input('Você deseja aceitar (s) ou não (n)?')

            if(resposta == 's'):
                print('Você aceitou!')
                saude -= 2
                vidasocial -= 1
                fama += 1

            elif (resposta == 'n'):
                print('Você não aceitou!')

            mostrar_mochila()

        # Cenário 2: Decidiu se aprimorar em uma linguagem  s- d- vs-- f-
        if cenario == 2:
            contador += 1
            print('\nDecidiu se aprimorar em uma linguagem')
            resposta = input('Você deseja aceitar (s) ou não (n)?')

            if(resposta == 's'):
                print('Você aceitou!')
                saude -= 1
                dinheiro -= 1
                vidasocial -= 2
                fama -= 1

            elif (resposta == 'n'):
                print('Você não aceitou!')

            mostrar_mochila()

        # Cenário 3: Cliente chato propondo um freela de 5 mil reais  s--- d+++ vs-- f0
        if cenario == 3:
            contador += 1
            print(
                '\nAquele cliente chato está te oferecendo um freela pagando 5 mil reais')
            resposta = input('Você deseja aceitar (s) ou não (n)?')

            if(resposta == 's'):
                print('Você aceitou!')
                saude -= 3
                dinheiro += 3
                vidasocial -= 2

            elif (resposta == 'n'):
                print('Você não aceitou!')

            mostrar_mochila()

        # Cenário 4: Promoção na empresa  s-- d++ vs- f+
        if cenario == 4:
            contador += 1
            print('\nVocê ganhou uma promoção')
            resposta = input('Você deseja aceitar (s) ou não (n)?')

            if(resposta == 's'):
                print('Você aceitou!')
                saude -= 2
                dinheiro += 2
                vidasocial -= 1
                fama += 1

            elif (resposta == 'n'):
                print('Você não aceitou!')

            mostrar_mochila()

        # Cenário 5: Férias da empresa s+++ d-- vs++ f+
        if cenario == 5:
            contador += 1
            print('\nA empresa te propos um período de férias')
            resposta = input('Você deseja aceitar (s) ou não (n)?')
            if(resposta == 's'):
                print('Você aceitou!')
                saude += 3
                dinheiro -= 2
                vidasocial += 2
                fama += 1

            elif (resposta == 'n'):
                print('Você não aceitou!')

            mostrar_mochila()

        # Cenário 6: Promoção de peças novas pro PC s- d-- vs---- f++
        if cenario == 6:
            contador += 1
            print('\nChegaram várias promoções de peças para dar aquele up no setup')
            resposta = input('Você deseja aceitar (s) ou não (n)?')

            if(resposta == 's'):
                print('Você aceitou!')
                saude -= 1
                dinheiro -= 2
                vidasocial -= 4
                fama += 2

            elif (resposta == 'n'):
                print('Você não aceitou!')

            mostrar_mochila()

    if(saude > 0 and dinheiro > 0 and vidasocial > 0 and fama > 0):
        print("\nPARABÉNS, VOCÊ CONSEGUIU! =)\n")
    else:
        print("\nNão foi dessa vez! :(\n")

    print('-------PLACAR FINAL-------')
    mostrar_mochila()


if __name__ == "__main__":
    main()

# %%
# Projeto Final


from random import randint

saude = 10
dinheiro = 10
vidasocial = 10
fama = 10
contador = 0


def mostraMochila():
    print(f"""
        Saúde: {saude}
        Dinheiro: {dinheiro}
        Vida Social: {vidasocial}
        Fama: {fama}
        """)
    print('--------------------------')

def imprimeMenu():
  print("-----------Menu-----------")
  print("(1) Iniciar Jogo")
  print("(2) Mostrar Crédito")
  print("(3) Finalizar")
  print("--------------------------")
  opcao = input("Escolha uma opção: ")
  return int(opcao)

def iniciaJogo():
  global saude
  global dinheiro
  global vidasocial
  global fama
  global contador

  print('Olá! Vou te apresentar alguns cenários que acontecem no dia a dia de uma pessoa desenvolvedora e quero saber se você aceitaria ou não vivenciá-lo.')
  print('Lembre-se: Em cada cenário existe a possibilidade de ganhar ou perder saúde, dinheiro, vida social e fama. Seu objetivo é MANTER O EQUILÍBRIO.')
  print('Vamos começar?!')
  print('--------------------------')

  while (saude > 0 and dinheiro > 0 and vidasocial > 0 and fama > 0) and contador < 6:
      cenario = randint(1, 6)

      # Cenário 1: Desenvolvimento de um software promissor s-- d0 vs- f+
      if cenario == 1:
        contador += 1
        print('\nRecebeu uma proposta de desenvolvimento de um software promissor')
        resposta = input('Você deseja aceitar (s) ou não (n)?')

        if(resposta == 's'):
          print('Você aceitou!')
          saude -= 2
          vidasocial -= 1
          fama += 1

        elif (resposta == 'n'):
          print('Você não aceitou!')

        mostrar_mochila()

      # Cenário 2: Decidiu se aprimorar em uma linguagem  s- d- vs-- f-
      if cenario == 2:
        contador += 1
        print('\nDecidiu se aprimorar em uma linguagem')
        resposta = input('Você deseja aceitar (s) ou não (n)?')

        if(resposta == 's'):
          print('Você aceitou!')
          saude -= 1
          dinheiro -= 1
          vidasocial -= 2
          fama -= 1

        elif(resposta == 'n'):
          print('Você não aceitou!')

        mostrar_mochila()

      # Cenário 3: Cliente chato propondo um freela de 5 mil reais  s--- d+++ vs-- f0
      if cenario == 3:
        contador += 1
        print('\nAquele cliente chato está te oferecendo um freela pagando 5 mil reais')
        resposta = input('Você deseja aceitar (s) ou não (n)?')

        if(resposta == 's'):
            print('Você aceitou!')
            saude -= 3
            dinheiro += 3
            vidasocial -= 2

        elif(resposta == 'n'):
          print('Você não aceitou!')

        mostrar_mochila()

      # Cenário 4: Promoção na empresa  s-- d++ vs- f+
      if cenario == 4:
        contador += 1
        print('\nVocê ganhou uma promoção')
        resposta = input('Você deseja aceitar (s) ou não (n)?')

        if(resposta == 's'):
          print('Você aceitou!')
          saude -= 2
          dinheiro += 2
          vidasocial -= 1
          fama += 1

        elif (resposta == 'n'):
          print('Você não aceitou!')

          mostrar_mochila()

      # Cenário 5: Férias da empresa s+++ d-- vs++ f+
      if cenario == 5:
        contador += 1
        print('\nA empresa te propos um período de férias')
        resposta = input('Você deseja aceitar (s) ou não (n)?')
        if(resposta == 's'):
          print('Você aceitou!')
          saude += 3
          dinheiro -= 2
          vidasocial += 2
          fama += 1

        elif (resposta == 'n'):
          print('Você não aceitou!')

        mostrar_mochila()

      # Cenário 6: Promoção de peças novas pro PC s- d-- vs---- f++
      if cenario == 6:
        contador += 1
        print('\nChegaram várias promoções de peças para dar aquele up no setup')
        resposta = input('Você deseja aceitar (s) ou não (n)?')

        if(resposta == 's'):
          print('Você aceitou!')
          saude -= 1
          dinheiro -= 2
          vidasocial -= 4
          fama += 2

        elif (resposta == 'n'):
          print('Você não aceitou!')

        mostrar_mochila()

  if(saude > 0 and dinheiro > 0 and vidasocial > 0 and fama > 0):
    print("\nPARABÉNS, VOCÊ CONSEGUIU! =)\n")
  else:
    print("\nNão foi dessa vez! :(\n")

  print('-------PLACAR FINAL-------')
  mostrar_mochila()

def mostraCreditos():
  print("\nDesenvolvido por: Rayanne Bertolace Lima")

def finalizaJogo():
  print("\nFinalizando jogo...")

def main(): 
  opcao = imprimeMenu()
  while(opcao <= 0 or opcao > 3):
    print("\nOpção inválida! Escolha 1, 2 ou 3.\n")
    opcao = imprimeMenu()
    
  if opcao == 1:
    iniciaJogo()
  elif opcao == 2:
    mostraCreditos()
  elif opcao == 3:
    finalizaJogo()
  else:
    print("\nOpção inválida! Escolha 1, 2 ou 3.\n")
    imprimeMenu()

if __name__ == "__main__":
  main()

# %% [markdown]
# ---
